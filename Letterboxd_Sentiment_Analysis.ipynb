# %%
import csv
def fix_rows():
    input_file = "movie_reviews_v2.csv"
    output_file = "fixed_movie_reviews.csv"
    with open(input_file, 'r', newline='') as infile, open(output_file, 'w', newline='') as outfile:
        reader = csv.reader(infile, delimiter="\t")
        writer = csv.writer(outfile)
        writer.writerow(["id","movie_title","release_year","synopsis","review","first_100"])

        for row in reader:
            for row in reader:
                if len(row) > 6: #Deals with rows with more than 6 columns
                    merged_columns = ' '.join(row[4:-1])
                    new_row = row[:4] + [merged_columns] + [row[-1]]
                    writer.writerow(new_row)
                elif len(row) == 6: 
                    writer.writerow(row)
                else: #If row has less than 6 columns, we skip
                    pass
fix_rows()

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pandas as pd
import emoji
from emoji import UNICODE_EMOJI
def is_emoji(s, language="en"):
    return s in UNICODE_EMOJI[language]

# add space near your emoji

def normalize():
    df = pd.read_csv("fixed_movie_reviews.csv")
    df['review'] = df['review'].apply(str) #Turn into str type
    #df['review'] = df['review'].apply(lambda x: emoji.replace_emoji(x, replace=lambda chars, data_dict: ' '.join(data_dict['en'].split('_')).strip(':')))
    df['review'] = df['review'].str.lower() #Turn into lowercase
    df['review'] = df['review'].apply(lambda x:emoji.demojize(x))
    
    df['review'] = df['review'].apply(lambda x: re.sub(r'[^a-zA-Z\s\U0001F600-\U0001F64F\U0001F300-\U0001F5FF\U0001F680-\U0001F6FF\U0001F700-\U0001F77F\U0001F780-\U0001F7FF\U0001F800-\U0001F8FF\U0001F900-\U0001F9FF\U0001FA00-\U0001FA6F\U0001FA70-\U0001FAFF\U0001FB00-\U0001FBFF\U0001FC00-\U0001FCFF\U0001FD00-\U0001FDFF\U0001FE00-\U0001FEFF\U0001FF00-\U0001FFFF]+', ' ', x)) #Gets rid of non-alphabet
    df['review'] = df['review'].apply(lambda x: word_tokenize(x)) #Tokenizes
    stop_words = stopwords.words('english')
    new_stopwords = ["movie","film","one","think","character","thats","im","something","thing"] #Additional custom stopwords
    stop_words.extend(new_stopwords)
    stop_words = set(stop_words)
    df['review'] = df['review'].apply(lambda x: [word for word in x if word not in stop_words]) #Remove all stopwords
    df['review'] = df['review'].apply(lambda x: ' '.join(x)) #Join back review after removing stopwords
    
    #df['review'] = df['review'].apply(lambda x: emoji.replace_emoji(x, '')) #Remove emojis
    
    df.to_csv('normalized_movie_reviews_with_emojis_as_text.csv', index=False)
    
normalize()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
import csv
def analyze_sentiment(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment = analyzer.polarity_scores(text) #Uses NLTK built in analyzer
    if sentiment['compound'] >= 0.05: #If score is more than 0.05, mark as positive
        return 'Positive'
    elif sentiment['compound'] <= -0.05: #If score is less than -0.05, mark as negative
        return 'Negative'
    else:
        return 'Neutral' #Otherwise, neutral
def make_columns(text):
    analyzer = SentimentIntensityAnalyzer()
    sentiment = analyzer.polarity_scores(text)
    return sentiment["neg"], sentiment["neu"],sentiment["pos"],sentiment["compound"]
def nltk_sentiment_analysis():
    df = pd.read_csv("normalized_movie_reviews_with_emojis_as_text.csv")
    df['review'] = df['review'].apply(str)
    df['sentiment'] = df['review'].apply(analyze_sentiment) #Applies analyzer to the reviews, create new column for sentiment
    df['neg_scores'], df["neu_scores"],df["pos_scores"],df["compound_scores"]= zip(*df['review'].apply(make_columns))
    df.to_csv('nltk_analyzed_movie_reviews_with_emojis.csv', index=False)
nltk_sentiment_analysis()

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import pandas as pd
import csv
def sklearn_sentiment_analysis():
    df = pd.read_csv("nltk_analyzed_movie_reviews.csv")
    labels = df["sentiment"].values
    vectorizer = TfidfVectorizer (max_features=2500, min_df=7, max_df=0.8, stop_words=stopwords.words('english'))
    #max_features=2500 uses the 2500 more frequent words to make "bag of words" feature vector
    #min_df=0.8 only uses words that occur in max 80% of reviews (we dont want words that are too common)
    #min_df=7, uses words that appear in at least 7 reviews
    
    
    processed_features = vectorizer.fit_transform(df['review'].values.astype('U')).toarray()
    #Fits our reviews data into the vector
    X_train, X_test, y_train, y_test = train_test_split(processed_features, labels, test_size=0.2, random_state=0)
    #Splits data set into training, testing, and validating. I think test size is 20%, so training is 80%
    text_classifier = RandomForestClassifier(n_estimators=200, random_state=0)
    #I used the randomforestclassifier to learn
    text_classifier.fit(X_train, y_train)
    predictions = text_classifier.predict(X_test)
    #Call prediction function on the randomforestclassifier class
    print(confusion_matrix(y_test,predictions))
    print(classification_report(y_test,predictions))
    print(accuracy_score(y_test, predictions))
sklearn_sentiment_analysis()
# Out:
# [[2125  312 1108]
#  [ 106 2152  250]
#  [ 363  230 5437]]
#               precision    recall  f1-score   support
#
#     Negative       0.82      0.60      0.69      3545
#      Neutral       0.80      0.86      0.83      2508
#     Positive       0.80      0.90      0.85      6030
#
#     accuracy                           0.80     12083
#    macro avg       0.81      0.79      0.79     12083
# weighted avg       0.81      0.80      0.80     12083
#
# 0.8039394190184557

# %%
import matplotlib.pyplot as plt
import pandas as pd
def generate_word_cloud():
    df = pd.read_csv("normalized_movie_reviews.csv")
    text = " ".join(str(review) for review in df.review)
    stopwords = set(STOPWORDS)
    stopwords.update(["make", "much","hes"])
    wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
    
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
generate_word_cloud()

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
import numpy
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

def encode_text(text):
    
    encoded_text = tokenizer(str(text), return_tensors="pt", padding=True)
    return encoded_text
def roberta_analysis(encoded_text):
    #reshape = numpy.reshape(encoded_text, (1,696))
    scores_dict = {
        'roberta_neg' : [],
        'roberta_neu' : [],
        'roberta_pos' : []
    }
    try:
        output = model(**encoded_text)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)
        scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
        }
        #neg_scores, neu_scores, pos_scores = scores[0], scores[1], scores[2]
        
        return scores_dict
    except RuntimeError as e:
        print("Error:", e)
        return {
            'roberta_neg': None,
            'roberta_neu': None,
            'roberta_pos': None
        }

    

df = pd.read_csv("normalized_movie_reviews_with_emojis.csv")
#token_val = [str(i) for i in df['review'].values]
df['encoded_text'] = df['review'].apply(encode_text)
sentiment_scores_df = df['encoded_text'].apply(lambda x: roberta_analysis(x))
sentiment_scores_df = pd.DataFrame(sentiment_scores_df.tolist())  # Convert to DataFrame
df = pd.concat([df, sentiment_scores_df], axis=1)

df.to_csv('roberta_analyzed_movie_reviews_with_emojis.csv', index=False)
# Out:
# Error: The expanded size of the tensor (696) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 696].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (2778) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 2778].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (866) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 866].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (750) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 750].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (16386) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 16386].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (782) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 782].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (527) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 527].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (621) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 621].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (713) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 713].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1166) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1166].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1022) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1022].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (2306) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 2306].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (2688) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 2688].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (845) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 845].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (901) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 901].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (552) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 552].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (871) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 871].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1213) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1213].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (3766) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 3766].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1427) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1427].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1410) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1410].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (768) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 768].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (544) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 544].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1400) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1400].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (748) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 748].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1150) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1150].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (583) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 583].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (997) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 997].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1567) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1567].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1564) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1564].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1952) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1952].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1011) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1011].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (2557) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 2557].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (953) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 953].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (718) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 718].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (530) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 530].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (844) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 844].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (601) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 601].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1284) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1284].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1054) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1054].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1360) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1360].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1343) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1343].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (960) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 960].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (676) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 676].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (871) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 871].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (529) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 529].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (755) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 755].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (801) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 801].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (1221) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 1221].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (754) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 754].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (542) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 542].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (914) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 914].  Tensor sizes: [1, 514]
# Error: The expanded size of the tensor (597) must match the existing size (514) at non-singleton dimension 1.  Target sizes: [1, 597].  Tensor sizes: [1, 514]

# %%
roberta = pd.read_csv('roberta_analyzed_movie_reviews_with_emojis.csv')
vader = pd.read_csv('nltk_analyzed_movie_reviews_with_emojis.csv')
combined_analysis = pd.merge(roberta, vader, how='inner')
combined_analysis.columns
columns_to_keep = ['roberta_neg', 'roberta_neu', 'roberta_pos', 'neg_scores', 'neu_scores', 'pos_scores']
combined_analysis = combined_analysis.loc[:, columns_to_keep]

combined_analysis.to_csv('combined_analysis.csv', index=False)

# %%
import seaborn as sns
sns.pairplot(data=combined_analysis, x_vars = ['roberta_neg', 'roberta_neu', 'roberta_pos', 'neg_scores', 'neu_scores', 'pos_scores'], 
             y_vars =['roberta_neg', 'roberta_neu', 'roberta_pos','neg_scores', 'neu_scores', 'pos_scores'])

# %%
import seaborn as sns
#create seaborn boxplots by group
sns.boxplot(data=combined_analysis)
#modify axis labels
plt.title('Sentiment Score by Method')
plt.ylabel('Sentiment Score')
plt.xlabel('Methods')
plt.xticks(rotation=90)
plt.show()

# %%
combined_analysis['roberta_neg'].isna().sum()
# Out:
# 2
